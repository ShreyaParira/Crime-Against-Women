# %% [markdown]
# # **Stop violence againts Womens**

# %% [markdown]
# This data is collated from https://data.gov.in. It has state-wise and district level data on the various crimes committed against women between 2001 to 2014.
# The crimes included are:
# * Rape
# * Kidnapping and Abduction
# * Dowry Deaths
# * Assault on women with intent to outrage her modesty
# * Insult to modesty of Women
# * Cruelty by Husband or his Relatives
# * Importation of Girls

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# **Read csv file**

# %%
filepath = 'crimes_against_women_2001-2014 (1).csv'
data = pd.read_csv(filepath)
data
# Out:
#        Unnamed: 0        STATE/UT           DISTRICT  Year  Rape  \
# 0               0  ANDHRA PRADESH           ADILABAD  2001    50
# 1               1  ANDHRA PRADESH          ANANTAPUR  2001    23
# 2               2  ANDHRA PRADESH           CHITTOOR  2001    27
# 3               3  ANDHRA PRADESH           CUDDAPAH  2001    20
# 4               4  ANDHRA PRADESH      EAST GODAVARI  2001    23
# ...           ...             ...                ...   ...   ...
# 10672         832     Lakshadweep        Lakshadweep  2014     1
# 10673         833     Lakshadweep  Total District(s)  2014     1
# 10674         834      Puducherry           Karaikal  2014     3
# 10675         835      Puducherry         Puducherry  2014     7
# 10676         836      Puducherry  Total District(s)  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 0                            30            16
# 1                            30             7
# 2                            34            14
# 3                            20            17
# 4                            26            12
# ...                         ...           ...
# 10672                         0             0
# 10673                         0             0
# 10674                         1             0
# 10675                         6             1
# 10676                         7             1
#
#        Assault on women with intent to outrage her modesty  \
# 0                                                    149
# 1                                                    118
# 2                                                    112
# 3                                                    126
# 4                                                    109
# ...                                                  ...
# 10672                                                  1
# 10673                                                  1
# 10674                                                 12
# 10675                                                 20
# 10676                                                 32
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                              34                                  175
# 1                              24                                  154
# 2                              83                                  186
# 3                              38                                   57
# 4                              58                                  247
# ...                           ...                                  ...
# 10672                           2                                    0
# 10673                           2                                    0
# 10674                           1                                    1
# 10675                           7                                    3
# 10676                           8                                    4
#
#        Importation of Girls
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 10672                     0
# 10673                     0
# 10674                     0
# 10675                     0
# 10676                     0
#
# [10677 rows x 11 columns]

# %% [markdown]
# **I create a copy of the dataset I will work on**

# %%
df = data.copy()

# %% [markdown]
# **A little overview on the dataset**

# %%
df.head(2)
# Out:
#    Unnamed: 0        STATE/UT   DISTRICT  Year  Rape  \
# 0           0  ANDHRA PRADESH   ADILABAD  2001    50
# 1           1  ANDHRA PRADESH  ANANTAPUR  2001    23
#
#    Kidnapping and Abduction  Dowry Deaths  \
# 0                        30            16
# 1                        30             7
#
#    Assault on women with intent to outrage her modesty  \
# 0                                                149
# 1                                                118
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
#
#    Importation of Girls
# 0                     0
# 1                     0

# %% [markdown]
# A little description of the features:
# - **'Unnamed:0'** -> index;
# - **State or UT Name** -> name of the State or Union Territories
# - **District** -> Name of the district
# - **Year** -> year when it happend
# - The other columns have a self explanatory name

# %% [markdown]
# **Then let's see what types of data we have**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10677 entries, 0 to 10676
# Data columns (total 11 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           10677 non-null  int64
#  1   STATE/UT                                             10677 non-null  object
#  2   DISTRICT                                             10677 non-null  object
#  3   Year                                                 10677 non-null  int64
#  4   Rape                                                 10677 non-null  int64
#  5   Kidnapping and Abduction                             10677 non-null  int64
#  6   Dowry Deaths                                         10677 non-null  int64
#  7   Assault on women with intent to outrage her modesty  10677 non-null  int64
#  8   Insult to modesty of Women                           10677 non-null  int64
#  9   Cruelty by Husband or his Relatives                  10677 non-null  int64
#  10  Importation of Girls                                 10677 non-null  int64
# dtypes: int64(9), object(2)
# memory usage: 917.7+ KB

# %% [markdown]
# **See the shapes of the dataset**

# %%
df.shape
# Out:
# (10677, 11)

# %% [markdown]
# **Drop the index column that is useless**

# %%
df = df.drop(columns = 'Unnamed: 0')
df
# Out:
#              STATE/UT           DISTRICT  Year  Rape  \
# 0      ANDHRA PRADESH           ADILABAD  2001    50
# 1      ANDHRA PRADESH          ANANTAPUR  2001    23
# 2      ANDHRA PRADESH           CHITTOOR  2001    27
# 3      ANDHRA PRADESH           CUDDAPAH  2001    20
# 4      ANDHRA PRADESH      EAST GODAVARI  2001    23
# ...               ...                ...   ...   ...
# 10672     Lakshadweep        Lakshadweep  2014     1
# 10673     Lakshadweep  Total District(s)  2014     1
# 10674      Puducherry           Karaikal  2014     3
# 10675      Puducherry         Puducherry  2014     7
# 10676      Puducherry  Total District(s)  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 0                            30            16
# 1                            30             7
# 2                            34            14
# 3                            20            17
# 4                            26            12
# ...                         ...           ...
# 10672                         0             0
# 10673                         0             0
# 10674                         1             0
# 10675                         6             1
# 10676                         7             1
#
#        Assault on women with intent to outrage her modesty  \
# 0                                                    149
# 1                                                    118
# 2                                                    112
# 3                                                    126
# 4                                                    109
# ...                                                  ...
# 10672                                                  1
# 10673                                                  1
# 10674                                                 12
# 10675                                                 20
# 10676                                                 32
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                              34                                  175
# 1                              24                                  154
# 2                              83                                  186
# 3                              38                                   57
# 4                              58                                  247
# ...                           ...                                  ...
# 10672                           2                                    0
# 10673                           2                                    0
# 10674                           1                                    1
# 10675                           7                                    3
# 10676                           8                                    4
#
#        Importation of Girls
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 10672                     0
# 10673                     0
# 10674                     0
# 10675                     0
# 10676                     0
#
# [10677 rows x 10 columns]

# %% [markdown]
# **Drop the duplicates of the states**

# %%
df["STATE/UT"]=df.apply(lambda row:row['STATE/UT'].replace(" ","").lower(),axis=1)
df['STATE/UT'].replace("delhiut",'delhi',inplace=True)

# %% [markdown]
# **But excuse the ignorance, which are the States and union territories of India?**

# %%
states=df['STATE/UT'].unique()
print("Number of states/territories without duplicates: ", len(states))

print(states)
# Out:
# Number of states/territories without duplicates:  36
# ['andhrapradesh' 'arunachalpradesh' 'assam' 'bihar' 'chhattisgarh' 'goa'
#  'gujarat' 'haryana' 'himachalpradesh' 'jammu&kashmir' 'jharkhand'
#  'karnataka' 'kerala' 'madhyapradesh' 'maharashtra' 'manipur' 'meghalaya'
#  'mizoram' 'nagaland' 'odisha' 'punjab' 'rajasthan' 'sikkim' 'tamilnadu'
#  'tripura' 'uttarpradesh' 'uttarakhand' 'westbengal' 'a&nislands'
#  'chandigarh' 'd&nhaveli' 'daman&diu' 'delhi' 'lakshadweep' 'puducherry'
#  'telangana']

# %% [markdown]
# **Create a new feature that contains a sum of all the crimes of a country**

# %%
df['total_crimes']=(df['Rape']+df['Kidnapping and Abduction']+df['Dowry Deaths']+
                       df['Assault on women with intent to outrage her modesty']+
                       df['Insult to modesty of Women']+df['Cruelty by Husband or his Relatives']+
                       df['Importation of Girls'])
df
# Out:
#             STATE/UT           DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0      andhrapradesh           ADILABAD  2001    50                        30
# 1      andhrapradesh          ANANTAPUR  2001    23                        30
# 2      andhrapradesh           CHITTOOR  2001    27                        34
# 3      andhrapradesh           CUDDAPAH  2001    20                        20
# 4      andhrapradesh      EAST GODAVARI  2001    23                        26
# ...              ...                ...   ...   ...                       ...
# 10672    lakshadweep        Lakshadweep  2014     1                         0
# 10673    lakshadweep  Total District(s)  2014     1                         0
# 10674     puducherry           Karaikal  2014     3                         1
# 10675     puducherry         Puducherry  2014     7                         6
# 10676     puducherry  Total District(s)  2014    10                         7
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0                16                                                149
# 1                 7                                                118
# 2                14                                                112
# 3                17                                                126
# 4                12                                                109
# ...             ...                                                ...
# 10672             0                                                  1
# 10673             0                                                  1
# 10674             0                                                 12
# 10675             1                                                 20
# 10676             1                                                 32
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                              34                                  175
# 1                              24                                  154
# 2                              83                                  186
# 3                              38                                   57
# 4                              58                                  247
# ...                           ...                                  ...
# 10672                           2                                    0
# 10673                           2                                    0
# 10674                           1                                    1
# 10675                           7                                    3
# 10676                           8                                    4
#
#        Importation of Girls  total_crimes
# 0                         0           454
# 1                         0           356
# 2                         0           456
# 3                         0           278
# 4                         0           475
# ...                     ...           ...
# 10672                     0             4
# 10673                     0             4
# 10674                     0            18
# 10675                     0            44
# 10676                     0            62
#
# [10677 rows x 11 columns]

# %% [markdown]
# **Let's create a dataframe that contains the sum of the crimes of all the states group by years**

# %%
#total_crimes
crimes=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls','total_crimes']

df1=pd.DataFrame()
for i in crimes:
    df1[i]=df.groupby(['Year'])[i].sum()
    
df1
# Out:
#        Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  32150                     29290         13702
# 2002  32746                     29012         13644
# 2003  31694                     26592         12416
# 2004  36466                     31156         14052
# 2005  36718                     31500         13574
# 2006  38696                     34828         15236
# 2007  41474                     40832         16186
# 2008  42934                     45878         16344
# 2009  42794                     51482         16766
# 2010  44344                     59590         16782
# 2011  48412                     71130         17236
# 2012  49846                     76524         16466
# 2013  67414                    103762         16166
# 2014  73470                    114622         16910
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                              68248
# 2002                                              67886
# 2003                                              65878
# 2004                                              69134
# 2005                                              68350
# 2006                                              73234
# 2007                                              77468
# 2008                                              80826
# 2009                                              77422
# 2010                                              81226
# 2011                                              85936
# 2012                                              90702
# 2013                                             141478
# 2014                                             164470
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                       19492                                98340
# 2002                       20310                                98474
# 2003                       24650                               101406
# 2004                       20002                               116242
# 2005                       19968                               116638
# 2006                       19932                               126256
# 2007                       21900                               151860
# 2008                       24428                               162688
# 2009                       22018                               179092
# 2010                       19922                               188082
# 2011                       17140                               198270
# 2012                       18346                               213054
# 2013                       25178                               237732
# 2014                       19470                               245754
#
#       Importation of Girls  total_crimes
# Year
# 2001                   228        261450
# 2002                   152        262224
# 2003                    92        262728
# 2004                   178        287230
# 2005                   298        287046
# 2006                   134        308316
# 2007                   122        349842
# 2008                   134        373232
# 2009                    96        389670
# 2010                    72        410018
# 2011                   160        438284
# 2012                   118        465056
# 2013                    62        591792
# 2014                    26        634722

# %% [markdown]
# **And a more simple look of the total number number of crimes in each year with a barplot**

# %%
plt.figure(figsize=(15,8))
sns
sns.barplot(x = df1.index,y = df1['total_crimes'])

# %% [markdown]
# **Have a more simple look also about all the crimes**

# %%
fig,axes = plt.subplots(4,2,figsize=(100,100))

sns.barplot(ax=axes[0][0],x = df1.index, y = df1['Rape'])
sns.barplot(ax=axes[0][1],x = df1.index, y = df1['Dowry Deaths'])
sns.barplot(ax=axes[1][0],x = df1.index, y = df1['Kidnapping and Abduction'])
sns.barplot(ax=axes[1][1],x = df1.index, y = df1['Assault on women with intent to outrage her modesty'])
sns.barplot(ax=axes[2][0],x = df1.index, y = df1['Insult to modesty of Women'])
sns.barplot(ax=axes[2][1],x = df1.index, y = df1['Cruelty by Husband or his Relatives'])
sns.barplot(ax=axes[3][0],x = df1.index, y = df1['Importation of Girls'])
sns.barplot(ax=axes[3][1],x = df1.index, y = df1['total_crimes'])

# %% [markdown]
# **Comparing What Part Of Total Crimes are Dowry Deaths.**

# %%
sns.lineplot(data=df1,x=df1.index,y=df1['Dowry Deaths'])

sns.lineplot(data=df1,x=df1.index,y=df1['total_crimes'])
print((df1['Dowry Deaths'].sum()/df1['total_crimes'].sum())*100)
# Out:
# 4.049150539028602

# %% [markdown]
# **Comparing What Part Of Total Crimes are Rape.**

# %%
sns.lineplot(data=df1,x=df1.index,y=df1['Rape'])

sns.lineplot(data=df1,x=df1.index,y=df1['total_crimes'])
print((df1['Rape'].sum()/df1['total_crimes'].sum())*100)
# Out:
# 11.634787216650599

# %% [markdown]
# **Comparing What Part Of Total Crimes are Kidnapping and Abduction .**

# %%
sns.lineplot(data=df1,x=df1.index,y=df1['Kidnapping and Abduction'])

sns.lineplot(data=df1,x=df1.index,y=df1['total_crimes'])
print((df1['Kidnapping and Abduction'].sum()/df1['total_crimes'].sum())*100)
# Out:
# 14.022034684991949

# %% [markdown]
# **Comparing What Part Of Total Crimes are Assault on women with intent to outrage her modesty .**

# %%
sns.lineplot(data=df1,x=df1.index,y=df1['Assault on women with intent to outrage her modesty'])

sns.lineplot(data=df1,x=df1.index,y=df1['total_crimes'])
print((df1['Assault on women with intent to outrage her modesty'].sum()/df1['total_crimes'].sum())*100)
# Out:
# 22.779910590967773

# %% [markdown]
# **Comparing What Part Of Total Crimes are Insult to modesty of Women .**

# %%
sns.lineplot(data=df1,x=df1.index,y=df1['Insult to modesty of Women'])

sns.lineplot(data=df1,x=df1.index,y=df1['total_crimes'])
print((df1['Insult to modesty of Women'].sum()/df1['total_crimes'].sum())*100)
# Out:
# 5.50126747356533

# %% [markdown]
# **Comparing What Part Of Total Crimes are Cruelty by Husband or his Relatives .**

# %%
sns.lineplot(data=df1,x=df1.index,y=df1['Cruelty by Husband or his Relatives'])

sns.lineplot(data=df1,x=df1.index,y=df1['total_crimes'])
print((df1['Cruelty by Husband or his Relatives'].sum()/df1['total_crimes'].sum())*100)
# Out:
# 41.97767217064009

# %% [markdown]
# **Comparing What Part Of Total Crimes are Importation of Girls .**

# %%
sns.lineplot(data=df1,x=df1.index,y=df1['Importation of Girls'])

sns.lineplot(data=df1,x=df1.index,y=df1['total_crimes'])
print((df1['Importation of Girls'].sum()/df1['total_crimes'].sum())*100)
# Out:
# 0.03517732415565966

# %% [markdown]
# **From the figures that we have attained it can be clearly seen that cruelty by husband or his relatives is the most common crime whereas Importation of girls is the least common crime in India.**

# %% [markdown]
# # **What are the States/UT with more crimes?**

# %%
states=df['STATE/UT'].unique()

# %%
df_state=pd.DataFrame()
for i in crimes:
    df_state[i]=df.groupby(['STATE/UT'])[i].sum()
    

plt.figure(figsize=(100,100))
df_new=df_state.sort_values(by=['total_crimes'])
sns.barplot(data = df_new,x = df_state.index,y = 'total_crimes')

# %%
df_state = df_state.sort_values(by = 'total_crimes', ascending = False)
most_criminal_states = df_state[:3]
most_criminal_states
# Out:
#                 Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# uttarpradesh   51150                    135906         57256
# andhrapradesh  32150                     34504         13844
# westbengal     47876                     61158         12308
#
#                Assault on women with intent to outrage her modesty  \
# STATE/UT
# uttarpradesh                                               91212
# andhrapradesh                                             126952
# westbengal                                                 66908
#
#                Insult to modesty of Women  \
# STATE/UT
# uttarpradesh                        53130
# andhrapradesh                       86964
# westbengal                           5348
#
#                Cruelty by Husband or his Relatives  Importation of Girls  \
# STATE/UT
# uttarpradesh                                193738                     6
# andhrapradesh                               280906                    34
# westbengal                                  344124                   254
#
#                total_crimes
# STATE/UT
# uttarpradesh         582398
# andhrapradesh        575354
# westbengal           537976

# %% [markdown]
# As we can see the states with more crimes in are **Uttar Pradesh**, **Andhra Pradesh**, **West Bengal**, **Rajasthan**, **Madhya Pradesh**.

# %%
least_criminal_states = df_state[-3:]
least_criminal_states
# Out:
#              Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# d&nhaveli     132                       224             2
# daman&diu      60                        44             6
# lakshadweep    20                         2             0
#
#              Assault on women with intent to outrage her modesty  \
# STATE/UT
# d&nhaveli                                                  106
# daman&diu                                                   40
# lakshadweep                                                 14
#
#              Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# STATE/UT
# d&nhaveli                            12                                   90
# daman&diu                             4                                   76
# lakshadweep                           4                                   14
#
#              Importation of Girls  total_crimes
# STATE/UT
# d&nhaveli                       0           566
# daman&diu                       0           230
# lakshadweep                     0            54

# %% [markdown]
# While the states with least crimes are **Sikkim**, **Nagaland**, **D&nhaveli**, **Daman & Diu** and **Lakshadweep**

# %% [markdown]
# # **Sort Analysis of the 3 states with most crimes**

# %% [markdown]
# **Uttar Pradesh**

# %% [markdown]
# ![](https://dz01iyojmxk8t.cloudfront.net/wp-content/uploads/2019/09/18165138/FB-uttar-pradesh.jpg)

# %%
df_up=df.loc[df['STATE/UT']=='uttarpradesh']

df_up1=pd.DataFrame()
for i in crimes:
    df_up1[i]=df_up.groupby(['Year'])[i].sum()
    
df_up1
# Out:
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  3916                      5758          4422
# 2002  2830                      4596          3786
# 2003  1822                      2998          2644
# 2004  2794                      4648          3416
# 2005  2434                      4512          3128
# 2006  2628                      5102          3596
# 2007  3296                      6726          4152
# 2008  3742                      8878          4474
# 2009  3518                     10156          4464
# 2010  3126                     10936          4434
# 2011  4084                     15050          4644
# 2012  3926                     15820          4488
# 2013  6100                     19474          4670
# 2014  6934                     21252          4938
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               5740
# 2002                                               4290
# 2003                                               2196
# 2004                                               3800
# 2005                                               3670
# 2006                                               4192
# 2007                                               5044
# 2008                                               5910
# 2009                                               5564
# 2010                                               5586
# 2011                                               6910
# 2012                                               6494
# 2013                                              14606
# 2014                                              17210
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                        5150                                14730
# 2002                        3774                                11358
# 2003                        9940                                 5252
# 2004                        5364                                 9900
# 2005                        5762                                 9010
# 2006                        5428                                10408
# 2007                        5764                                15300
# 2008                        6748                                16624
# 2009                        5048                                17132
# 2010                          22                                15956
# 2011                           6                                14242
# 2012                          16                                15322
# 2013                          50                                17562
# 2014                          58                                20942
#
#       Importation of Girls  total_crimes
# Year
# 2001                     0         39716
# 2002                     0         30634
# 2003                     0         24852
# 2004                     6         29928
# 2005                     0         28516
# 2006                     0         31354
# 2007                     0         40282
# 2008                     0         46376
# 2009                     0         45882
# 2010                     0         40060
# 2011                     0         44936
# 2012                     0         46066
# 2013                     0         62462
# 2014                     0         71334

# %%
fig,axes = plt.subplots(4,2,figsize=(20,20))
sns.barplot(ax=axes[0][0],x = df_up1.index, y = df_up1['Rape'])
sns.barplot(ax=axes[0][1],x = df_up1.index, y = df_up1['Dowry Deaths'])
sns.barplot(ax=axes[1][0],x = df_up1.index, y = df_up1['Kidnapping and Abduction'])
sns.barplot(ax=axes[1][1],x = df_up1.index, y = df_up1['Assault on women with intent to outrage her modesty'])
sns.barplot(ax=axes[2][0],x = df_up1.index, y = df_up1['Insult to modesty of Women'])
sns.barplot(ax=axes[2][1],x = df_up1.index, y = df_up1['Cruelty by Husband or his Relatives'])
sns.barplot(ax=axes[3][0],x = df_up1.index, y = df_up1['Importation of Girls'])
sns.barplot(ax=axes[3][1],x = df_up1.index, y = df_up1['total_crimes'])

# %% [markdown]
# **Andhra Pradesh**

# %% [markdown]
# ![](https://static.investindia.gov.in/s3fs-public/styles/clusters_banner/public/2018-12/Industrial%20Corridors_Andhra%20Pradesh.jpg?itok=GV9bbAc8)

# %%
df_ap=df.loc[df['STATE/UT']=='andhrapradesh']
df_ap1=pd.DataFrame()
for i in crimes:
    df_a=df_ap.groupby(['Year'])[i].sum()
    df_ap1[i]=df_a
df_ap1
# Out:
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  1742                      1530           840
# 2002  2004                      1708           898
# 2003  1892                      1862           932
# 2004  2032                      2060          1024
# 2005  1870                      1990           886
# 2006  2098                      2658          1038
# 2007  2140                      3128          1226
# 2008  2514                      2792          1112
# 2009  2376                      3052          1092
# 2010  2724                      3062          1176
# 2011  2884                      3224          1198
# 2012  2682                      2806          1008
# 2013  3270                      3190           984
# 2014  1922                      1442           430
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               7088
# 2002                                               7598
# 2003                                               8256
# 2004                                               7634
# 2005                                               7190
# 2006                                               9068
# 2007                                               8812
# 2008                                               9460
# 2009                                              10294
# 2010                                               9268
# 2011                                               9698
# 2012                                               9632
# 2013                                              13860
# 2014                                               9094
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                        4542                                11582
# 2002                        4048                                14036
# 2003                        4572                                16334
# 2004                        4620                                16776
# 2005                        5016                                17392
# 2006                        4822                                18328
# 2007                        6632                                22670
# 2008                        7102                                20612
# 2009                        7040                                22594
# 2010                        9124                                24160
# 2011                        7316                                26752
# 2012                        7428                                26778
# 2013                        9404                                30168
# 2014                        5298                                12724
#
#       Importation of Girls  total_crimes
# Year
# 2001                    14         27338
# 2002                     0         30292
# 2003                    10         33858
# 2004                     4         34150
# 2005                     6         34350
# 2006                     0         38012
# 2007                     0         44608
# 2008                     0         43592
# 2009                     0         46448
# 2010                     0         49514
# 2011                     0         51072
# 2012                     0         50334
# 2013                     0         60876
# 2014                     0         30910

# %%
fig,axes = plt.subplots(4,2,figsize=(20,20))
sns.barplot(ax=axes[0][0],x = df_ap1.index, y = df_ap1['Rape'])
sns.barplot(ax=axes[0][1],x = df_ap1.index, y = df_ap1['Dowry Deaths'])
sns.barplot(ax=axes[1][0],x = df_ap1.index, y = df_ap1['Kidnapping and Abduction'])
sns.barplot(ax=axes[1][1],x = df_ap1.index, y = df_ap1['Assault on women with intent to outrage her modesty'])
sns.barplot(ax=axes[2][0],x = df_ap1.index, y = df_ap1['Insult to modesty of Women'])
sns.barplot(ax=axes[2][1],x = df_ap1.index, y = df_ap1['Cruelty by Husband or his Relatives'])
sns.barplot(ax=axes[3][0],x = df_ap1.index, y = df_ap1['Importation of Girls'])
sns.barplot(ax=axes[3][1],x = df_ap1.index, y = df_ap1['total_crimes'])

# %% [markdown]
# **West Bengal**

# %% [markdown]
# ![](https://th.bing.com/th/id/R0f210f33da156a2e1de7ad9d0949311b?rik=o9cFpTWvc8Ss%2fQ&riu=http%3a%2f%2fimages.indianexpress.com%2f2016%2f06%2fwest-bengal-7591.jpg&ehk=XuEsEPX9PjUhFg53g%2fnpeV%2bxOdPUnypgBCCCCJANBEc%3d&risl=&pid=ImgRaw)

# %%
df_wb=df.loc[df['STATE/UT']=='westbengal']
df_wb1=pd.DataFrame()
for i in crimes:
    df_w=df_wb.groupby(['Year'])[i].sum()
    df_wb1[i]=df_w
df_wb1
# Out:
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  1418                      1390           530
# 2002  1518                      1388           546
# 2003  2004                      1602           658
# 2004  2950                      2036           792
# 2005  3372                      2078           892
# 2006  3462                      2398           890
# 2007  4212                      3180           902
# 2008  4526                      3814           902
# 2009  4672                      4374          1012
# 2010  4622                      5528          1014
# 2011  4726                      7422          1020
# 2012  4092                      8336          1186
# 2013  3370                      7660           962
# 2014  2932                      9952          1002
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                               1908
# 2002                                               1928
# 2003                                               2372
# 2004                                               3132
# 2005                                               3144
# 2006                                               3674
# 2007                                               4562
# 2008                                               4792
# 2009                                               3884
# 2010                                               4930
# 2011                                               4726
# 2012                                               6690
# 2013                                               9826
# 2014                                              11340
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                          96                                 7718
# 2002                          68                                 8138
# 2003                         142                                 9896
# 2004                         128                                12668
# 2005                         108                                13872
# 2006                         126                                14828
# 2007                         198                                19800
# 2008                         188                                27326
# 2009                         216                                32224
# 2010                         326                                35592
# 2011                         400                                39544
# 2012                        1112                                39730
# 2013                        1154                                36232
# 2014                        1086                                46556
#
#       Importation of Girls  total_crimes
# Year
# 2001                     6         13066
# 2002                     2         13588
# 2003                     2         16676
# 2004                    24         21730
# 2005                   122         23588
# 2006                     2         25380
# 2007                    10         32864
# 2008                    10         41558
# 2009                    10         46392
# 2010                    16         52028
# 2011                     0         57838
# 2012                    24         61170
# 2013                    18         59222
# 2014                     8         72876

# %%
fig,axes = plt.subplots(4,2,figsize=(20,20))
sns.barplot(ax=axes[0][0],x = df_wb1.index, y = df_wb1['Rape'])
sns.barplot(ax=axes[0][1],x = df_wb1.index, y = df_wb1['Dowry Deaths'])
sns.barplot(ax=axes[1][0],x = df_wb1.index, y = df_wb1['Kidnapping and Abduction'])
sns.barplot(ax=axes[1][1],x = df_wb1.index, y = df_wb1['Assault on women with intent to outrage her modesty'])
sns.barplot(ax=axes[2][0],x = df_wb1.index, y = df_wb1['Insult to modesty of Women'])
sns.barplot(ax=axes[2][1],x = df_wb1.index, y = df_wb1['Cruelty by Husband or his Relatives'])
sns.barplot(ax=axes[3][0],x = df_wb1.index, y = df_wb1['Importation of Girls'])
sns.barplot(ax=axes[3][1],x = df_wb1.index, y = df_wb1['total_crimes'])

# %% [markdown]
# **I hope that these numbers will drop drastically in the coming years because in the modern era it makes no sense, in my opinion, to carry on the stereotype of women inferior to men and consequently all these crimes.**
